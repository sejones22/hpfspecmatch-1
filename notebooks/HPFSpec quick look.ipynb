# %%
from importlib import reload
import os
import glob2
import pandas as pd
import numpy as np
import sys

# %%
import hpfspec
import hpfspecmatch
hpfspecmatch
# Out:
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# DIRNAME: /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspecmatch-0.1.1-py3.8.egg
# /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspecmatch-0.1.1-py3.8.egg/library/20210811_specmatch_nir/FITS
# <module 'hpfspecmatch' from '/home/sejones/anaconda3/lib/python3.8/site-packages/hpfspecmatch-0.1.1-py3.8.egg/hpfspecmatch/__init__.py'>

# %%
#filename = '../input/GJ_1148/Slope-20190320T034635_R01.optimal.fits'
#filename = '../input/G_9-40/Slope-20190301T023135_R01.optimal.fits'
#filename = '../input/HPFTemplate/Template_Kepler-45_Fudge1.fits'
#filename = '../input/HPFTemplate/Template_TOI-3757_Fudge1.fits'
filename_temp = '../input/HPFTemplate/Template_TOI-1728_Fudge1.fits'

# %%
filename = '../input/20200228_toi1728/Slope-20200329T031711_R01.optimal.fits' # 156.97723

# %%
H = hpfspec.HPFSpectrum(filename, targetname='TIC-285048486')
# Out:
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/TIC-285048486.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: -42.66667+- 0.00000km/s
# RVabs iteration #2: -42.60738+- 0.00000km/s
# berv=-21.485477964510828,rv=-42.60737747949716

# %%
H = hpfspec.HPFSpectrum(filename_temp, targetname='TIC-285048486')
# Out:
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/TIC-285048486.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-562de3fa93ed> in <module>
# ----> 1 H = hpfspec.HPFSpectrum(filename_temp, targetname='TIC-285048486')
#
# ~/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/hpfspec.py in __init__(self, filename, targetname, deblaze, ccf_redshift, tell_err_factor, sky_err_factor)
#     107         if ccf_redshift:
#     108             v = np.linspace(-125,125,1501)
# --> 109             _, rabs = self.rvabs_for_orders(v,orders=[5],plot=False)
#     110             self.rv = np.median(rabs)
#     111             self.redshift(rv=self.rv)
#
# ...

# %%
H.sn18
# Out:
# 156.97723

# %%
# 59.650826 ../input/TOI-3757/Slope-20211029T080441_R01.optimal.fits

# %%
H.plot_order(5)

# %%
hpfspec.spec_help.

# %%
H.object
# Out:
# 'GJ_1148'

# %%
H.w
# Out:
# array([[ 8079.03571871,  8079.09520453,  8079.1546831 , ...,
#          8183.47119231,  8183.51333737,  8183.5554732 ],
#        [ 8188.22186388,  8188.28215408,  8188.34243685, ...,
#          8294.05099852,  8294.09370746,  8294.13640704],
#        [ 8300.40167986,  8300.46277794,  8300.52386855, ...,
#          8407.66124273,  8407.7045373 ,  8407.74782245],
#        ...,
#        [12119.54090534, 12119.62896636, 12119.71701694, ...,
#         12274.44805555, 12274.51064145, 12274.57321373],
#        [12366.9845251 , 12367.0742617 , 12367.1639876 , ...,
#         12524.86329411, 12524.9270603 , 12524.99081251],
#        [12624.75511054, 12624.846543  , 12624.93796463, ...,
#         12785.70060667, 12785.76558061, 12785.83054004]])

# %%
H.w_shifted[5]
# Out:
# array([8656.1848703 , 8656.24855388, 8656.31222964, ..., 8767.97111087,
#        8768.01624614, 8768.06137163])

# %%
H.w_shifted[5][-1]
# Out:
# 8768.061371630973

# %%
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
HDU = fits.open('../input/20200228_toi1728/Slope-20200329T031711_R01.optimal.fits')
HDU_temp = fits.open('../input/HPFTemplate/Template_TOI-1728_Fudge1.fits')

# %%
SciWl = HDU[7].data
SciFlux = HDU[1].data
TemplateSciWl = HDU_temp[7].data
TemplateSciFlux = HDU_temp[1].data
o=5

# %%
#plt.plot(SciWl[o], SciFlux[o])
plt.plot(TemplateSciWl[o], TemplateSciFlux[o], c='crimson')

# %%
TemplateSciWl[o,500:600]
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan])
