# %%
import hpfspecmatch
import hpfspec
# Out:
# AIRTOVAC (TRUE for HARPS, FALSE for HPF):  False
# DIRNAME: /home/sejones/hpfspecmatch

# %%
HLS = hpfspec.HPFSpecList(filelist = hpfspecmatch.config.LIBRARY_FITSFILES)
# Out:
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.0-py3.8.egg/hpfspec/data/target_files/HD_24238.config
# No section: 'targetinfo' File does not exist!
# Querying SIMBAD for data
# Saving to file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.0-py3.8.egg/hpfspec/data/target_files/HD_24238.config
# ra 58.766009166666656
# dec 61.16680722222222
# pmra 437.904
# pmdec -245.599
# px 47.5927
# rv 38749.0
# epoch 2451545.0
# Done
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE for HPF):  False
# RVabs iteration #1: 39.83333+- 0.00000km/s
# RVabs iteration #2: 39.53935+- 0.00000km/s
# berv=6.08110408565654,rv=39.53934989283167
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.0-py3.8.egg/hpfspec/data/target_files/HD_35112.config
# No section: 'targetinfo' File does not exist!
# Querying SIMBAD for data
# ...

# %%
HLS
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b36bb730534f> in <module>
# ----> 1 HLS[0]
#
# TypeError: 'HPFSpecList' object is not subscriptable

# %%
for i,x in enumerate(hpfspecmatch.config.LIBRARY_FITSFILES):
    H = hpfspec.HPFSpectrum(x);
    print(i, H.target)
# Out:
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.0-py3.8.egg/hpfspec/data/target_files/HD_24238.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE for HPF):  False
# RVabs iteration #1: -112.33333+- 0.00000km/s
# RVabs iteration #2: -108.48812+- 0.00000km/s
# berv=6.08110408565654,rv=-108.4881221909557
# 0 HD_24238, ra=58.7660, dec=61.1668, pmra=437.904, pmdec=-245.599, rv=38.7490, px=47.5927, epoch=2451545.0
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.0-py3.8.egg/hpfspec/data/target_files/HD_35112.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE for HPF):  False
# RVabs iteration #1: 38.16667+- 0.00000km/s
# RVabs iteration #2: 38.57547+- 0.00000km/s
# berv=12.063036503004753,rv=38.57547240668419
# 1 HD_35112, ra=80.6562, dec=2.6032, pmra=64.449, pmdec=-180.087, rv=36.1480, px=50.3943, epoch=2451545.0
# ...

# %%
H = hpfspec.HPFSpectrum(hpfspecmatch.config.LIBRARY_FITSFILES[83])
# Out:
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.0-py3.8.egg/hpfspec/data/target_files/LSPM_J0255+2652E.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE for HPF):  False
# RVabs iteration #1: 33.16667+- 0.00000km/s
# RVabs iteration #2: 33.20837+- 0.00000km/s
# berv=28.22743400680787,rv=33.20837298379716

# %%
H.object
# Out:
# 'HD_24238'

# %% [markdown]
# 0 HD_24238
# 5 GJ_3507
# 82 LHS_3353
# 83 LSPM_J0255+2652E
