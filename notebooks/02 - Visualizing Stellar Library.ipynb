# %% [markdown]
# ## Import packages

# %%
from importlib import reload
import os
import glob2
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import hpfspec
import hpfspecmatch
# Out:
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# DIRNAME: /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspecmatch-0.1.1-py3.8.egg
# /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspecmatch-0.1.1-py3.8.egg/library/20210406_specmatch_nir_library/FITS

# %% [markdown]
# ## Read in Library

# %%
# download library if does not exist
hpfspecmatch.utils.get_library()
# Out:
# Library already exists. Skipping download
# Library path is: /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspecmatch-0.1.1-py3.8.egg/library/20210406_specmatch_nir_library

# %%
# List of stellar library fits files
library_fitsfiles = hpfspecmatch.config.LIBRARY_FITSFILES

# Read in all files as a HPFSpecList object
HLS =  hpfspec.HPFSpecList(filelist=library_fitsfiles)
# Out:
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/HD_24238.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: 39.83333+- 0.00000km/s
# RVabs iteration #2: 39.53960+- 0.00000km/s
# berv=6.08110408565654,rv=39.53960337179467
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/HD_35112.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: 38.16667+- 0.00000km/s
# RVabs iteration #2: 38.57628+- 0.00000km/s
# berv=12.063036503004753,rv=38.57628059153686
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/GJ_3358.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: -45.50000+- 0.00000km/s
# RVabs iteration #2: -45.36883+- 0.00000km/s
# berv=9.770838896949163,rv=-45.36882854698408
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/HD_53927.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: 20.50000+- 0.00000km/s
# RVabs iteration #2: 20.15647+- 0.00000km/s
# berv=19.376120140770933,rv=20.156471651064184
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/HD_61606.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: -17.83333+- 0.00000km/s
# RVabs iteration #2: -17.72647+- 0.00000km/s
# berv=24.111441252189323,rv=-17.72646732047087
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/GJ_3507.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: 35.66667+- 0.00000km/s
# RVabs iteration #2: 35.89217+- 0.00000km/s
# berv=-24.16206576724576,rv=35.89217146515273
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/GJ_3743.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: -9.33333+- 0.00000km/s
# RVabs iteration #2: -9.18858+- 0.00000km/s
# berv=18.261563112685042,rv=-9.18858111310533
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/HD_87883.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: 10.00000+- 0.00000km/s
# RVabs iteration #2:  9.82694+- 0.00000km/s
# berv=28.21631999785097,rv=9.82694494369327
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/NLTT_26380.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: -35.66667+- 0.00000km/s
# RVabs iteration #2: -35.57605+- 0.00000km/s
# berv=26.167540901951085,rv=-35.57604718378768
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/KIC_9955598.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: -28.50000+- 0.00000km/s
# RVabs iteration #2: -27.98581+- 0.00000km/s
# berv=10.210962372277908,rv=-27.985805448855647
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/NLTT_31697.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: -5.83333+- 0.00000km/s
# RVabs iteration #2: -6.09753+- 0.00000km/s
# berv=-7.007651233557575,rv=-6.097525354337008
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/GJ_483.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: 10.16667+- 0.00000km/s
# RVabs iteration #2: 10.40493+- 0.00000km/s
# berv=18.65081822443051,rv=10.404932289860803
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/HD_186306.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: -59.50000+- 0.00000km/s
# RVabs iteration #2: -59.83706+- 0.00000km/s
# berv=10.193881449537365,rv=-59.837058382101084
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/HD_173701.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: -45.00000+- 0.00000km/s
# RVabs iteration #2: -44.81879+- 0.00000km/s
# berv=2.234233987627185,rv=-44.81878586680254
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/NLTT_32537.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: 27.33333+- 0.00000km/s
# RVabs iteration #2: 27.06518+- 0.00000km/s
# berv=20.17324465059718,rv=27.065181611313488
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/BD+00_444.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: 73.50000+- 0.00000km/s
# RVabs iteration #2: 73.39535+- 0.00000km/s
# berv=-8.15076585903598,rv=73.39534646485002
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/*_111_Tau_B.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: 38.50000+- 0.00000km/s
# RVabs iteration #2: 38.89976+- 0.00000km/s
# berv=12.474248238189897,rv=38.899764088363014
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/HD
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/HD_196124.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: -41.50000+- 0.00000km/s
# RVabs iteration #2: -41.81687+- 0.00000km/s
# berv=-26.92253328651699,rv=-41.816865295549064
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/GJ_4183.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: -49.16667+- 0.00000km/s
# RVabs iteration #2: -49.16591+- 0.00000km/s
# berv=14.953825164336392,rv=-49.16590596905171
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/GJ_840.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: -12.66667+- 0.00000km/s
# RVabs iteration #2: -12.68631+- 0.00000km/s
# berv=21.100046907515885,rv=-12.686309851621147
# Reading from file /home/sejones/anaconda3/lib/python3.8/site-packages/hpfspec-0.1.1-py3.8.egg/hpfspec/data/target_files/NLTT_57303.config
# WARNING: LEAP UPDATE=FALSE
# Barycentric shifting
# AIRTOVAC (TRUE for HARPS, FALSE TRUE HPF):  False
# RVabs iteration #1: -12.16667+- 0.00000km/s
# RVabs iteration #2: -12.14184+- 0.00000km/s
# berv=20.682710614737598,rv=-12.141844592353674

# %%
# list library stars contained in HPFSpecList object
HLS.splist
# Out:
# [HPFSpec(HD_24238,sn18=469.4),
#  HPFSpec(HD_35112,sn18=334.1),
#  HPFSpec(GJ_3358,sn18=266.5),
#  HPFSpec(HD_53927,sn18=289.7),
#  HPFSpec(HD_61606,sn18=423.1),
#  HPFSpec(GJ_3507,sn18=322.1),
#  HPFSpec(GJ_3743,sn18=513.9),
#  HPFSpec(HD_87883,sn18=338.5),
#  HPFSpec(NLTT_26380,sn18=313.2),
#  HPFSpec(KIC_9955598,sn18=243.7),
#  HPFSpec(NLTT_31697,sn18=377.9),
#  HPFSpec(GJ_483,sn18=438.7),
#  HPFSpec(HD_186306,sn18=272.9),
#  HPFSpec(HD_173701,sn18=438.2),
#  HPFSpec(NLTT_32537,sn18=330.1),
#  HPFSpec(BD+00_444,sn18=345.0),
#  HPFSpec(*_111_Tau_B,sn18=424.8),
#  HPFSpec(HD_59582,sn18=196.4),
#  HPFSpec(GJ_3494,sn18=297.1),
#  HPFSpec(NLTT_21526,sn18=355.6),
#  HPFSpec(GJ_9304,sn18=468.5),
#  HPFSpec(HD_85488,sn18=373.3),
#  HPFSpec(GJ_418,sn18=360.4),
#  HPFSpec(GJ_15_B,sn18=523.1),
#  HPFSpec(LSPM_J1916+0510,sn18=288.4),
#  HPFSpec(GJ_846,sn18=396.1),
#  HPFSpec(GJ_172,sn18=751.1),
#  HPFSpec(V*_V2689_Ori,sn18=314.6),
#  HPFSpec(GJ_251,sn18=568.0),
#  HPFSpec(HD_28343,sn18=430.7),
#  HPFSpec(GJ_105_B,sn18=487.9),
#  HPFSpec(GJ_109,sn18=501.0),
#  HPFSpec(GJ_2066,sn18=499.3),
#  HPFSpec(HD_260655,sn18=567.2),
#  HPFSpec(GJ_250_B,sn18=478.1),
#  HPFSpec(GJ_273,sn18=661.5),
#  HPFSpec(GJ_382,sn18=447.1),
#  HPFSpec(GJ_393,sn18=427.6),
#  HPFSpec(GJ_686,sn18=415.2),
#  HPFSpec(GJ_694,sn18=440.8),
#  HPFSpec(GJ_745_A,sn18=414.0),
#  HPFSpec(GJ_806,sn18=465.0),
#  HPFSpec(GJ_9066,sn18=487.1),
#  HPFSpec(GJ_87,sn18=725.2),
#  HPFSpec(GJ_908,sn18=755.0),
#  HPFSpec(GJ_849,sn18=405.4),
#  HPFSpec(GJ_96,sn18=459.8),
#  HPFSpec(GJ_4333,sn18=407.9),
#  HPFSpec(GJ_895,sn18=413.8),
#  HPFSpec(GJ_134,sn18=479.9),
#  HPFSpec(GJ_173,sn18=242.2),
#  HPFSpec(GJ_361,sn18=242.5),
#  HPFSpec(NLTT_28458,sn18=339.7),
#  HPFSpec(GJ_1148,sn18=409.2),
#  HPFSpec(GJ_458.2,sn18=418.3),
#  HPFSpec(BD+29_2279,sn18=379.7),
#  HPFSpec(GJ_70,sn18=503.5),
#  HPFSpec(GJ_4070,sn18=253.2),
#  HPFSpec(GJ_434,sn18=420.2),
#  HPFSpec(GJ_15_A,sn18=702.9),
#  HPFSpec(GJ_5,sn18=448.1),
#  HPFSpec(GJ_725_A,sn18=573.1),
#  HPFSpec(GJ_809,sn18=453.5),
#  HPFSpec(GJ_880,sn18=495.5),
#  HPFSpec(GJ_892,sn18=310.7),
#  HPFSpec(GJ_205,sn18=370.5),
#  HPFSpec(GJ_27,sn18=559.5),
#  HPFSpec(HD_4628,sn18=483.7),
#  HPFSpec(GJ_338_A,sn18=425.3),
#  HPFSpec(HD_88230,sn18=536.1),
#  HPFSpec(GJ_411,sn18=677.2),
#  HPFSpec(GJ_176,sn18=261.7),
#  HPFSpec(GJ_338_B,sn18=277.7),
#  HPFSpec(LSPM_J1105+4331W,sn18=295.9),
#  HPFSpec(GJ_699,sn18=763.7),
#  HPFSpec(GJ_436,sn18=513.4),
#  HPFSpec(GJ_649,sn18=429.6),
#  HPFSpec(GJ_649.1_C,sn18=484.9),
#  HPFSpec(GJ_658,sn18=511.5),
#  HPFSpec(LSPM_J1712+1821,sn18=495.1),
#  HPFSpec(LHS_3353,sn18=547.6),
#  HPFSpec(LSPM_J0255+2652E,sn18=655.3),
#  HPFSpec(HD_196124,sn18=551.8),
#  HPFSpec(GJ_4183,sn18=237.8),
#  HPFSpec(GJ_840,sn18=424.6),
#  HPFSpec(NLTT_57303,sn18=477.1)]

# %%
# More info on the targets
HLS.df
# Out:
#            OBJECT_ID                                           filename  \
# 0           HD_24238  /home/sejones/anaconda3/lib/python3.8/site-pac...
# 1           HD_35112  /home/sejones/anaconda3/lib/python3.8/site-pac...
# 2            GJ_3358  /home/sejones/anaconda3/lib/python3.8/site-pac...
# 3           HD_53927  /home/sejones/anaconda3/lib/python3.8/site-pac...
# 4           HD_61606  /home/sejones/anaconda3/lib/python3.8/site-pac...
# ..               ...                                                ...
# 81  LSPM_J0255+2652E  /home/sejones/anaconda3/lib/python3.8/site-pac...
# 82         HD_196124  /home/sejones/anaconda3/lib/python3.8/site-pac...
# 83           GJ_4183  /home/sejones/anaconda3/lib/python3.8/site-pac...
# 84            GJ_840  /home/sejones/anaconda3/lib/python3.8/site-pac...
# 85        NLTT_57303  /home/sejones/anaconda3/lib/python3.8/site-pac...
#
#     exptime        sn18       qprog         rv
# 0    330.15  469.407166  UT19-3-008  39.539603
# 1    330.15  334.070587  UT19-3-008  38.576281
# 2    330.15  266.529724  UT19-3-008 -45.368829
# 3    915.90  289.663055  UT19-3-008  20.156472
# 4    244.95  423.089783  UT19-3-008 -17.726467
# ..      ...         ...         ...        ...
# 81   649.65  655.342407  UT20-2-007  33.208675
# 82   969.15  551.781128  UT19-3-008 -41.816865
# 83   330.15  237.780945  UT20-2-007 -49.165906
# 84   330.15  424.589417  UT20-2-007 -12.686310
# 85   969.15  477.063782  UT20-2-007 -12.141845
#
# [86 rows x 6 columns]

# %%
# Read in required information on all of the 
# This has the Teff, Fe/H, and logg for all of the stars
# OBJECT_ID is the HPF name of the star
df_lib = pd.read_csv(hpfspecmatch.config.PATH_LIBRARY_DB)
df_lib
# Out:
#          Name  Teff  e_Teff     R*   e_R*  log(g)  e_log(g)  [Fe/H]  e_[Fe/H]  \
# 0   HD_102195  5277      60  0.850  0.050    4.50      0.05    0.10      0.05
# 1   HD_110463  4906      60  0.760  0.030    4.55      0.05    0.06      0.05
# 2   HD_110743  5198      60  0.840  0.050    4.47      0.05    0.01      0.05
# 3   HD_110833  4999      60  0.800  0.040    4.51      0.05    0.18      0.05
# 4   HD_112914  4816      60  0.700  0.030    4.51      0.05   -0.26      0.05
# ..        ...   ...     ...    ...    ...     ...       ...     ...       ...
# 81    GL_338B  3867      37  0.567  0.014    4.71      0.02   -0.15      0.10
# 82    GL_412A  3497      39  0.398  0.009    4.87      0.02   -0.40      0.10
# 83     GL_699  3222      10  0.187  0.001    5.11      0.01   -0.39      0.10
# 84  HIP_57087  3416      53  0.455  0.018    4.83      0.03    0.04      0.10
# 85  HIP_83043  3590      45  0.539  0.016    4.75      0.02   -0.04      0.10
#
#       M*  ...                                      simbadnames_x  \
# 0   0.89  ...  SPOCS_2802|LSPM_J1145+0249|TYC__275-157-1|ASCC...
# 1   0.80  ...  SPOCS_2843|V*_NP_UMa|NSV_19460|AC2000_1833644|...
# 2   0.84  ...  SBC9_3576|SPOCS_2844|LSPM_J1243+3420|TYC_2533-...
# 3   0.83  ...  SBC9_3625|PLX_2933|SPOCS_2845|LSPM_J1244+5145|...
# 4   0.71  ...  SBC9_1742|LSPM_J1259+4159|ASCC__409814|UCAC2__...
# ..   ...  ...                                                ...
# 81  0.57  ...  Karmn_J09144+526|PM_J09144+5241|ASCC__253742|2...
# 82  0.41  ...  Karmn_J11054+435|Gaia_DR2_778947814402405120|P...
# 83  0.16  ...  Karmn_J17578+046|PLX_4098|LSPM_J1757+0441|ASCC...
# 84  0.45  ...  Karmn_J11421+267|TYC_1984-2613-1|PLX_2704.1|1R...
# 85  0.52  ...  PLX_3857|LSPM_J1658+2544|ASCC__694128|UCAC2__4...
#
#                          ID_NAME         OBJECT_ID  \
# 0   Gaia_DR2_3799626935341796096        NLTT_28458
# 1   Gaia_DR2_1571411233756165248           GJ_3743
# 2   Gaia_DR2_1515243640027361024        NLTT_31697
# 3   Gaia_DR2_1568219729458240128            GJ_483
# 4   Gaia_DR2_1527631807474248448        NLTT_32537
# ..                           ...               ...
# 81  Gaia_DR2_1022456104850892928          GJ_338_B
# 82   Gaia_DR2_778947814402405120  LSPM_J1105+4331W
# 83  Gaia_DR2_4472832130942575872            GJ_699
# 84  Gaia_DR2_4017860992519744384            GJ_436
# 85  Gaia_DR2_4572835535272064768            GJ_649
#
#                                              filename  exptime        sn18  \
# 0   ../library/20201008_specmatch_nir/FITS/2_10219...   649.65  339.875092
# 1   ../library/20201008_specmatch_nir/FITS/15_1104...   649.65  514.133606
# 2   ../library/20201008_specmatch_nir/FITS/17_1107...   969.15  378.116333
# 3   ../library/20201008_specmatch_nir/FITS/18_1108...   202.35  438.896149
# 4   ../library/20201008_specmatch_nir/FITS/21_1129...   649.65  330.296814
# ..                                                ...      ...         ...
# 81  ../library/20201008_specmatch_nir/FITS/393_GL3...   127.80  277.841675
# 82  ../library/20201008_specmatch_nir/FITS/394_GL4...   127.80  295.986267
# 83  ../library/20201008_specmatch_nir/FITS/397_GL6...   330.15  764.023743
# 84  ../library/20201008_specmatch_nir/FITS/401_HIP...   649.65  513.594360
# 85  ../library/20201008_specmatch_nir/FITS/403_HIP...   330.15  429.857849
#
#           qprog          rv                               basenames  \
# 0    UT20-2-007    2.688682  Slope-20200428T055102_R01.optimal.fits
# 1    UT20-1-008   -9.188611  Slope-20191203T123535_R01.optimal.fits
# 2    UT20-2-007   -6.097251  Slope-20200402T041219_R01.optimal.fits
# 3    UT20-1-008   10.405539  Slope-20191221T105911_R01.optimal.fits
# 4    UT20-1-008   27.064545  Slope-20200108T094852_R01.optimal.fits
# ..          ...         ...                                     ...
# 81   UT19-3-008   12.475246  Slope-20191201T092225_R01.optimal.fits
# 82  PSU19-1-001   68.893501  Slope-20190319T041042_R01.optimal.fits
# 83  ENG18-3-003 -110.592499  Slope-20181003T014556_R01.optimal.fits
# 84  ENG20-1-003    9.568895  Slope-20200208T064809_R01.optimal.fits
# 85   UT20-1-008    4.318801  Slope-20200208T120619_R01.optimal.fits
#
#                                         simbadnames_y
# 0   NAME_Flegetonte|SPOCS_2802|LSPM_J1145+0249|TYC...
# 1   SPOCS_2843|V*_NP_UMa|NSV_19460|AC2000_1833644|...
# 2   SBC9_3576|SPOCS_2844|LSPM_J1243+3420|TYC_2533-...
# 3   SBC9_3625|PLX_2933|SPOCS_2845|LSPM_J1244+5145|...
# 4   SBC9_1742|LSPM_J1259+4159|ASCC__409814|UCAC2__...
# ..                                                ...
# 81  Karmn_J09144+526|PM_J09144+5241|ASCC__253742|2...
# 82  Karmn_J11054+435|Gaia_DR2_778947814402405120|P...
# 83  Karmn_J17578+046|PLX_4098|LSPM_J1757+0441|ASCC...
# 84  Karmn_J11421+267|TYC_1984-2613-1|PLX_2704.1|1R...
# 85  PLX_3857|LSPM_J1658+2544|ASCC__694128|UCAC2__4...
#
# [86 rows x 33 columns]

# %% [markdown]
# ## Plot Library

# %%
# Plot Teff vs Fe/H and Teff vs logg for all library stars
fig = plt.figure(figsize=(21,8.5))
gs = gridspec.GridSpec(1, 2)
ax = plt.subplot(gs[0, 0])
bx = plt.subplot(gs[0, 1])

ax.set_ylabel('Teff [K]',fontsize=19)
ax.set_xlabel('[Fe/H]',fontsize=19)
bx.set_xlabel('log(g)',fontsize=19.5)

ax.tick_params(labelsize=16)
bx.tick_params(labelsize=16)
ax.minorticks_on()
bx.minorticks_on()
bx.axes.get_yaxis().set_visible(False)
fig.subplots_adjust(wspace=0.05)

# Teff vs Fe/H
ax.errorbar(df_lib['[Fe/H]'], df_lib['Teff'],df_lib['e_Teff'],df_lib['e_[Fe/H]'],lw=0,elinewidth=1.,marker="o",mew=0.5,markersize=8,capsize=4);

# Teff vd logg
bx.errorbar(df_lib['log(g)'], df_lib['Teff'],df_lib['e_Teff'],df_lib['e_log(g)'],lw=0,elinewidth=1.,marker="o",mew=0.5,markersize=8,capsize=4);
